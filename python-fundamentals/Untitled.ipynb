# %%
var= "hello"
print (var)
print(type(var))
# Out:
# hello
# <class 'str'>

# %%
# This python for devops!
#in Pyhon integer come be with whole number and float will be decimal

type(1)
type(1.8)
# Out:
# float

# %%
print(type(0.1))
0.1*3==0.3

# this can solved by importing math function let me try that 
import math
math.isclose(0.1*3,0.3)
# Out:
# <class 'float'>
# True

# %%
print(9/2)
print(type(9/2))
print(9//2)
print(type(9//2))
# Out:
# 4.5
# <class 'float'>
# 4
# <class 'int'>

# %%
math_integer = 7/2
print(f"math_answer= {math_integer}")
# Out:
# math_answer= 3.5

# %%
import shutil
code, used , free = shutil.disk_usage("C:/")

disk_code= code / 10**9
disk_used= used / 10**9
disk_free= free / 10**9

print(f"disk usgae = {disk_code:.2f}")
print(f"disk used = {disk_used:.2f}")
print(f"disk usgae = {disk_free:.2f}")
# Out:
# disk usgae = 129.44
# disk used = 82.12
# disk usgae = 47.31
